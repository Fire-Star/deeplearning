# %% [markdown]
# ![image.png](attachment:d8d243fc-798f-4f03-8d2b-962b785b898a.png)
# ![image.png](attachment:b5d04a44-2476-4b57-bf09-4bb4da387ca1.png)
# ![image.png](attachment:e0510f90-c335-477b-b531-23ca3ac5372b.png)
# ![image.png](attachment:239518f9-d2ff-436d-b495-cd6e66d1166d.png)

# %%
weights = [
  # toes % win % fans
    [0.1, 0.1, -0.3], # hurt?
    [0.1, 0.2, 0.0], # win?
    [0.0, 1.3, 0.1] # sad?
]

def neural_network(inputs, weights):
    pred = vect_mat_mul(inputs, weights)
    return pred

toes = [8.5, 9.5, 9.9, 9.0]
wlrec = [0.65, 0.8, 0.8, 0.9]
nfans = [1.2, 1.3, 0.5, 1.0]

inputs = [toes[0], wlrec[0], nfans[0]]

# %%
wlrec = [0.65, 0.8, 0.8, 0.9]
inputs = wlrec[0]

pred = neural_network(inputs, weights)

pred
# Out:
# [0.195, 0.13, 0.5850000000000001]
