# %% [markdown]
# ![image.png](attachment:88d671f8-c966-4ace-9bec-661d44c2a582.png)
# ![image.png](attachment:738c1244-495f-4428-a10a-6c28beb1e66d.png)
# ![image.png](attachment:9a8af231-0b85-4cf9-8caa-5b495e64dd95.png)
# ![image.png](attachment:52b51661-cd6f-4882-a937-138c49b73e1d.png)

# %%
weights = [0.3, 0.2, 0.9]
def neural_network(inputs, weights):
    pred = ele_mul(inputs, weights)
    return pred


def ele_mul(number, vector):
    output = [0, 0, 0]
    assert(len(output) == len(vector))
    for i in range(len(vector)):
        output[i] = number * vector[i]
    return output

# %%
wlrec = [0.65, 0.8, 0.8, 0.9]
inputs = wlrec[0]

pred = neural_network(inputs, weights)

pred
# Out:
# [0.195, 0.13, 0.5850000000000001]
